# %%
import numpy as np
from scipy import linalg as sp_linalg
from matplotlib import pyplot as plt
from numpy.linalg import matrix_power
import math
import pandas as pd

detection1=pd.read_csv("Nuclear_detection_theo_version.csv")
#detection1.head(351)
detection2=pd.read_csv("Nuclear_detection_exp_version.csv")
#detection2.head(351)

plt.figure(figsize=(20,4))

plt.xticks(fontsize =22) #그래프 눈금 숫자 크기 조절
plt.yticks(fontsize =22) #그래프 눈금 숫자 크기 조절
plt.xlabel('time (us)',fontsize=25)
plt.ylabel('PL',fontsize=25)

plt.plot(detection1,'r^')
plt.plot(detection2,'b')

plt.legend(fontsize=20)
#plt.savefig('result.png')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
